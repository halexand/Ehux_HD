# %%
import os.path as op
from goatools import GOEnrichmentStudy
from goatools.obo_parser import GODag
from goatools.associations import read_associations
import pygraphviz
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-15-375b31b9668f> in <module>()
#       3 from goatools.obo_parser import GODag
#       4 from goatools.associations import read_associations
# ----> 5 import pygraphviz
#
# ImportError: No module named pygraphviz

# %%
# %%bash
# bash /Users/harrietalexander/bin/goatools/run.sh
# 1
# Out:
# Process is terminated.

# %%
import os
os.chdir("/Users/harrietalexander/bin/goatools/")
# %run scripts/find_enrichment.py --pval=0.05 --indent data/study data/population data/association
# Out:
# load obo file go-basic.obo
# 45322 nodes imported
# terms not found: set(['GO:0022627', 'GO:0022625'])
# # Generated by GOATOOLS v0.5.7 (2015-07-23)
# # min_ratio=None pval=0.05
# id	enrichment	description	ratio_in_study	ratio_in_pop	p_uncorrected	p_bonferroni	p_holm	p_sidak	p_fdr
# .GO:0003824	e	catalytic activity	106/276	7723/33239	1.6e-08	9.75e-05	9.75e-05	9.5e-05	n.a.
# ..GO:0016740	e	transferase activity	54/276	2976/33239	5.43e-08	0.000331	0.000331	0.000323	n.a.
# .....GO:0006464	e	cellular protein modification process	33/276	1727/33239	8.25e-06	0.0504	0.0503	0.0491	n.a.
# ....GO:0036211	e	protein modification process	33/276	1727/33239	8.25e-06	0.0504	0.0503	0.0491	n.a.
# ......GO:0006468	e	protein phosphorylation	22/276	922/33239	1.08e-05	0.0658	0.0658	0.0642	n.a.
# ...GO:0098599	e	palmitoyl hydrolase activity	3/276	7/33239	1.93e-05	0.118	0.118	0.115	n.a.
# ....GO:0008474	e	palmitoyl-(protein) hydrolase activity	3/276	7/33239	1.93e-05	0.118	0.118	0.115	n.a.
# ...

# %%
# %run scripts/plot_go_term.py --term=GO:0008135
# Out:
# load obo file go-basic.obo
# 45322 nodes imported
# GO:0008135	level-05	depth-05	translation factor activity, RNA binding [molecular_function]
# all parents: set(['GO:0003674', 'GO:0003723', 'GO:0003676', 'GO:0097159', 'GO:1901363', 'GO:0005488'])
# all children: set(['GO:0008079', 'GO:0016150', 'GO:0016149', 'GO:0003746', 'GO:0003747', 'GO:0003743'])
# lineage info for terms ['GO:0008135'] written to GO_lineage.png

# %%
# %%bash
# open GO_lineage.png
