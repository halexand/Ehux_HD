# %%
#Read in important paths 
import pandas as pd
import cPickle as cpk
import matplotlib as mpl
import sys
import numpy as np
sys.path.append("/Users/harrietalexander/anaconda/lib/python2.7/site-packages/matplotlib_venn-0.11-py2.7.egg")
sys.path.insert(1, '/Users/harrietalexander/anaconda/lib/python2.7/site-packages')
import matplotlib.pyplot as plt
from matplotlib_venn import venn3
from matplotlib import gridspec
from itertools import combinations
import palettable.colorbrewer as b2m
import palettable as pal
import glob
from Bio import SeqIO
from string import ascii_lowercase, ascii_uppercase
from matplotlib.colors import LogNorm, NoNorm

mpl.rcParams['pdf.fonttype']=42
# %matplotlib inline
def Calculate_Venn_comparison(hash):
    #input = a Hash of the form hash[Organism]=list of orthologus groups
    #Outputs a hash of the form key = all the variations of thes sets : list of orthologus genes in an inclusive way
    #It is inclusive so the set containing A uniq genes is going to contain all the genes for an org
    variations={}
    for i in range(len(hash)):
        for v in combinations(hash.keys(), i+1):
            vsets = [hash[x] for x in v]
            variations[tuple(sorted(v))]=reduce(lambda x,y: x.intersection(y), vsets)
    return variations

def GetDifference_Venn(variations):
    #Function takes the input from the above function and outputs a hash of the same format but 
    #each set is uniqe: e.g. there are no repeats of orthologus groups across sets. 
    outdict={}
    vkeys=variations.keys()
    #loop over each of the variable cases
    for v in variations:
        #create a set to do the comparisons
        vset=set(v)
        vdata_set=set(variations[v])
        #loop over all other variations
        for j in variations:
            #if v is a subset of jset we want to remove the items of jset from v set
            jdata_set=set(variations[j])
            jset=set(j)
            if vset.issubset(jset):
                if vset==jset:
                    pass
                else: 
                    newdata=vdata_set-jdata_set
                    vdata_set=newdata
        outdict[v]=vdata_set
    return outdict

ccmap=b2m.qualitative.Accent_8.get_mpl_colormap()

# %%
gFHash=cpk.load(open('../orthoMCL_output/Ehux_Dictionary.pickle', 'r'))
#load the GeneOrtholog:transcript hash
Hist_PD=pd.DataFrame(index=gFHash.keys(),columns=['NumGenes', 'Emi374', 'Emi379', 'Emi370', 'Emi219', 'Emihu1'])
Hist_PD=Hist_PD.fillna(0)
for i,key in enumerate(gFHash):
#     if i==100:
#         break
    l=len(gFHash[key])
    Hist_PD.loc[key, 'NumGenes']=l
    for transcript in gFHash[key]:
        org=transcript.split('|')[0]
        Hist_PD.loc[key,org]+=1

# %%
GenesInOrg={}
GenesInOrg['Emi219']=Hist_PD[Hist_PD.Emi219>0].index
GenesInOrg['Emi379']=Hist_PD[Hist_PD.Emi379>0].index
GenesInOrg['Emi370']=Hist_PD[Hist_PD.Emi370>0].index
GenesInOrg['Emi374']=Hist_PD[Hist_PD.Emi374>0].index
GenesInOrg['Emihu1']=Hist_PD[Hist_PD.Emihu1>0].index


def invert(d):
    return dict( (v,k) for k in d for v in d[k] )
gFHash_inverted=invert(gFHash)
Genes_In_Each_Cat=Calculate_Venn_comparison(GenesInOrg)
Genes_Uniq_Venn=GetDifference_Venn(Genes_In_Each_Cat)

f=open('../EhuxGenome_Core.tab','r')
Genome_paper_Core=[]
for line in f:
    protein='Emihu1|'+line.strip()
    Genome_paper_Core.append(protein)
#Get the Emihu unique set of genes  
Emihu1_unique=set()
for x in Genes_Uniq_Venn[('Emihu1',)]:
    if x in gFHash:
        Emihu1_unique.update(set(gFHash[x]))

        #compare the variable Ehux to the core genes identified in the paper: 

NewCore=[]
TruVar=[]
for gene in Emihu1_unique:
    if gene in Genome_paper_Core:
        NewCore.append(gene)
    else:
        TruVar.append(gene)
        

NewCore_og=set()
TruVar_og=set()
for gene in NewCore:
    NewCore_og.update([gFHash_inverted[gene]])
for gene in TruVar:
    TruVar_og.update([gFHash_inverted[gene]])

##Update the hash
Genes_Uniq_Venn_PaperUpdate=dict(Genes_Uniq_Venn)

Genes_Uniq_Venn_PaperUpdate[('Emihu1',)]=TruVar_og
core=set(Genes_Uniq_Venn_PaperUpdate[('Emi219', 'Emi370', 'Emi374', 'Emi379', 'Emihu1')])
core.update(NewCore_og)
Genes_Uniq_Venn_PaperUpdate[('Emi219', 'Emi370', 'Emi374', 'Emi379', 'Emihu1')]=core

CoreGenes=Genes_Uniq_Venn_PaperUpdate[('Emi219', 'Emi370', 'Emi374', 'Emi379', 'Emihu1')] #get the genes that are core to all organisms

# %% [markdown]
# #KEGG Orthology

# %%
KAAS_Hash={}
for line in open('KAAS_Ehux_Protein_Annotation.tab', 'r'):
    line=line.split()
    if len(line)>1:
        KAAS_Hash[line[0].strip()]=line[1].strip()
    else:
        KAAS_Hash[line[0].strip()]=None
# KAAS_Hashcpk.load(open('Kegg_Hash.pickle', 'r'))

# %%
newOG_KEGGHash={}
for gene in gFHash:
    newOG_KEGGHash[gene]=[]
    for transcript in gFHash[gene]:
        kegg=KAAS_Hash[transcript]
        if kegg in newOG_KEGGHash[gene]:
            pass
        elif kegg==None:
            pass
        else: 
            newOG_KEGGHash[gene].append(kegg)#

# %%
# #check for instances where an orthologus group has >1 annotation from KEGG. 
# c=0
# for k in newOG_KEGGHash:
#     if len(newOG_KEGGHash[k])>1:
#         c+=1
#         print newOG_KEGGHash[k]

# %%
#Read in ko00002 table
Kegg_masterDict_ko0002={}
file=open('ko00002_table.tab', 'r')
header=next(file)
header= header.split('\t')
for l in file:
    line=l.split('\t')
    kegg=line[0]
    a={}
    for i,e in enumerate(line):
        a[header[i]]=e
    Kegg_masterDict_ko0002[kegg]=a

# %% [markdown]
# ##Look at the composition of the original transcriptomes (no TPM)

# %% [markdown]
# ## Total number of transcripts

# %% [markdown]
# #KOG Orthology

# %%
#Read in KOG table
KOG_MasterDict={}
file=open('KOG/output/output.2', 'r')
header=next(file)
header= header.split('\t')
for l in file:
    line=l.split('\t')
    PID=line[0]
    a={}
    for i,e in enumerate(line):
        a[header[i].strip()]=e.strip()
    KOG_MasterDict[PID]=a

# %%
newOG_KOGHash={}
for gene in gFHash:
    newOG_KOGHash[gene]=[]
    for transcript in gFHash[gene]:
        if transcript in KOG_MasterDict:
            KOG=KOG_MasterDict[transcript]['class description']
            if KOG in newOG_KOGHash[gene]:
                pass
            else: 
                newOG_KOGHash[gene].append(KOG)
KOG_cts={}                
    
newOG_KOGHash
# Out:
# {'OG1_5_49213': ['General function prediction only'],
#  'OG1_5_49212': [],
#  'OG1_5_49211': ['Function unknown'],
#  'OG1_5_49210': [],
#  'OG1_5_49217': [],
#  'OG1_5_49216': [],
#  'OG1_5_49215': [],
#  'OG1_5_49214': [],
#  'OG1_5_49219': [],
#  'OG1_5_49218': [],
#  'OG1_5_44188': [],
#  'OG1_5_44189': [],
#  'OG1_5_38635': [],
#  'OG1_5_33209': [],
#  'OG1_5_33208': [],
#  'OG1_5_5328': ['Multiple classes'],
#  'OG1_5_5329': ['Carbohydrate transport and metabolism'],
#  'OG1_5_5322': [],
#  'OG1_5_5323': ['Translation, ribosomal structure and biogenesis'],
#  'OG1_5_5320': ['Extracellular structures'],
#  'OG1_5_5321': ['Lipid transport and metabolism',
#   'General function prediction only'],
#  'OG1_5_5326': ['Multiple classes'],
#  'OG1_5_5327': ['Posttranslational modification, protein turnover, chaperones'],
#  'OG1_5_5324': ['Function unknown'],
#  'OG1_5_5325': ['Multiple classes'],
#  'OG1_5_39463': [],
#  'OG1_5_39462': [],
#  'OG1_5_39461': [],
#  'OG1_5_39460': [],
#  'OG1_5_39467': ['Transcription'],
#  'OG1_5_39466': [],
#  'OG1_5_39465': ['Function unknown'],
#  'OG1_5_39464': ['Intracellular trafficking, secretion, and vesicular transport'],
#  'OG1_5_44184': [],
#  'OG1_5_39469': [],
#  'OG1_5_39468': [],
#  'OG1_5_44185': [],
#  'OG1_5_50268': [],
#  'OG1_5_50269': [],
#  'OG1_5_50260': [],
#  'OG1_5_50261': [],
#  'OG1_5_50262': [],
#  'OG1_5_50263': [],
#  'OG1_5_50264': [],
#  'OG1_5_50265': [],
#  'OG1_5_50266': ['Multiple classes'],
#  'OG1_5_50267': [],
#  'OG1_5_34969': [],
#  'OG1_5_34968': ['Inorganic ion transport and metabolism'],
#  'OG1_5_34965': ['Function unknown'],
#  'OG1_5_34964': ['RNA processing and modification'],
#  'OG1_5_34967': ['Multiple classes'],
#  'OG1_5_34966': ['Transcription'],
#  'OG1_5_34961': ['Amino acid transport and metabolism'],
#  'OG1_5_34960': ['Cytoskeleton'],
#  'OG1_5_34963': ['Multiple classes'],
#  'OG1_5_34962': ['Cell cycle control, cell division, chromosome partitioning'],
#  'OG1_5_9573': [],
#  'OG1_5_3869': [],
#  'OG1_5_3868': ['Function unknown'],
#  'OG1_5_3867': [],
#  'OG1_5_3866': ['Lipid transport and metabolism'],
#  'OG1_5_3865': [],
#  'OG1_5_3864': [],
#  'OG1_5_3863': [],
#  'OG1_5_3862': ['Carbohydrate transport and metabolism'],
#  'OG1_5_3861': [],
#  'OG1_5_3860': ['Multiple classes'],
#  'OG1_5_9570': ['Posttranslational modification, protein turnover, chaperones'],
#  'OG1_5_12055': ['Secondary metabolites biosynthesis, transport and catabolism'],
#  'OG1_5_9576': ['Transcription'],
#  'OG1_5_9575': ['Posttranslational modification, protein turnover, chaperones'],
#  'OG1_5_9574': [],
#  'OG1_5_37438': [],
#  'OG1_5_37439': [],
#  'OG1_5_19854': [],
#  'OG1_5_37432': ['Cytoskeleton'],
#  'OG1_5_37433': ['Transcription'],
#  'OG1_5_37430': [],
#  'OG1_5_37431': ['Multiple classes'],
#  'OG1_5_37436': [],
#  'OG1_5_37437': [],
#  'OG1_5_37434': [],
#  'OG1_5_37435': [],
#  'OG1_5_21808': [],
#  'OG1_5_21809': [],
#  'OG1_5_21800': ['Extracellular structures'],
#  'OG1_5_21801': ['Carbohydrate transport and metabolism'],
#  'OG1_5_21802': [],
#  'OG1_5_21803': [],
#  'OG1_5_21804': ['General function prediction only'],
#  'OG1_5_21805': [],
#  'OG1_5_21806': [],
#  'OG1_5_21807': [],
#  'OG1_5_5864': ['Function unknown'],
#  'OG1_5_31878': [],
#  'OG1_5_31879': [],
#  'OG1_5_31874': [],
#  'OG1_5_31875': [],
#  'OG1_5_31876': [],
#  'OG1_5_31877': [],
#  'OG1_5_31870': [],
#  'OG1_5_31871': [],
#  'OG1_5_31872': ['Amino acid transport and metabolism'],
#  'OG1_5_31873': [],
#  'OG1_5_19856': ['Intracellular trafficking, secretion, and vesicular transport'],
#  'OG1_5_55116': [],
#  'OG1_5_17691': ['General function prediction only'],
#  'OG1_5_35881': [],
#  'OG1_5_6212': ['General function prediction only'],
#  'OG1_5_35883': ['Signal transduction mechanisms'],
#  'OG1_5_46887': ['RNA processing and modification'],
#  'OG1_5_35882': [],
#  'OG1_5_46886': [],
#  'OG1_5_35885': [],
#  'OG1_5_50402': ['Signal transduction mechanisms'],
#  'OG1_5_46885': [],
#  'OG1_5_35884': [],
#  'OG1_5_46884': [],
#  'OG1_5_35887': [],
#  'OG1_5_46883': [],
#  'OG1_5_35886': ['Posttranslational modification, protein turnover, chaperones'],
#  'OG1_5_46882': [],
#  'OG1_5_46881': [],
#  'OG1_5_8849': ['Posttranslational modification, protein turnover, chaperones'],
#  'OG1_5_11596': [],
#  'OG1_5_30549': [],
#  'OG1_5_33201': [],
#  'OG1_5_8248': [],
#  'OG1_5_8249': [],
#  'OG1_5_33200': [],
#  'OG1_5_8242': ['Intracellular trafficking, secretion, and vesicular transport'],
#  'OG1_5_8243': ['RNA processing and modification'],
#  'OG1_5_8240': ['Energy production and conversion'],
#  'OG1_5_8241': [],
#  'OG1_5_8246': ['RNA processing and modification'],
#  'OG1_5_8247': ['Multiple classes'],
#  'OG1_5_8244': [],
#  'OG1_5_8245': ['Multiple classes',
#   'Transcription',
#   'RNA processing and modification'],
#  'OG1_5_16576': [],
#  'OG1_5_16577': [],
#  'OG1_5_7418': [],
#  'OG1_5_7419': ['Translation, ribosomal structure and biogenesis'],
#  'OG1_5_16572': ['Multiple classes'],
#  'OG1_5_16573': [],
#  'OG1_5_16570': [],
#  'OG1_5_16571': [],
#  'OG1_5_7412': ['Function unknown',
#   'Translation, ribosomal structure and biogenesis',
#   'Extracellular structures'],
#  'OG1_5_7413': ['Defense mechanisms'],
#  'OG1_5_7410': [],
#  'OG1_5_7411': [],
#  'OG1_5_7416': ['Translation, ribosomal structure and biogenesis'],
#  'OG1_5_7417': ['Cell cycle control, cell division, chromosome partitioning'],
#  'OG1_5_7414': [],
#  'OG1_5_16579': ['Posttranslational modification, protein turnover, chaperones'],
#  'OG1_5_12266': [],
#  'OG1_5_12267': [],
#  'OG1_5_12264': [],
#  'OG1_5_12265': [],
#  'OG1_5_12262': ['General function prediction only'],
#  'OG1_5_12263': [],
#  'OG1_5_12260': [],
#  'OG1_5_12261': ['Cytoskeleton'],
#  'OG1_5_33206': [],
#  'OG1_5_30541': [],
#  'OG1_5_12268': ['General function prediction only',
#   'Multiple classes',
#   'RNA processing and modification'],
#  'OG1_5_12269': ['Replication, recombination and repair'],
#  'OG1_5_30540': [],
#  'OG1_5_3032': ['Energy production and conversion'],
#  'OG1_5_41358': ['Multiple classes'],
#  'OG1_5_44954': [],
#  'OG1_5_19853': ['Lipid transport and metabolism'],
#  'OG1_5_42177': ['Transcription'],
#  'OG1_5_42176': [],
#  'OG1_5_42175': [],
#  'OG1_5_42174': [],
#  'OG1_5_42173': ['General function prediction only'],
#  'OG1_5_42172': [],
#  'OG1_5_36358': ['Intracellular trafficking, secretion, and vesicular transport'],
#  'OG1_5_41351': ['Extracellular structures'],
#  'OG1_5_42171': [],
#  'OG1_5_41894': [],
#  'OG1_5_42170': [],
#  'OG1_5_20434': [],
#  'OG1_5_31416': [],
#  'OG1_5_41896': ['General function prediction only'],
#  'OG1_5_41354': [],
#  'OG1_5_31417': [],
#  'OG1_5_20432': [],
#  'OG1_5_41355': [],
#  'OG1_5_31414': [],
#  'OG1_5_20433': [],
#  'OG1_5_31415': [],
#  'OG1_5_41893': [],
#  'OG1_5_34424': [],
#  'OG1_5_41892': [],
#  'OG1_5_34425': [],
#  'OG1_5_17225': [],
#  'OG1_5_17224': ['Signal transduction mechanisms'],
#  'OG1_5_17227': [],
#  'OG1_5_17226': [],
#  'OG1_5_17221': [],
#  'OG1_5_17220': [],
#  'OG1_5_17223': ['Multiple classes'],
#  'OG1_5_17222': [],
#  'OG1_5_45231': [],
#  'OG1_5_45230': [],
#  'OG1_5_45233': [],
#  'OG1_5_45232': [],
#  'OG1_5_17229': [],
#  'OG1_5_17228': ['Multiple classes'],
#  'OG1_5_45237': ['Cytoskeleton'],
#  'OG1_5_45236': ['Extracellular structures'],
#  'OG1_5_41899': [],
#  'OG1_5_41898': [],
#  'OG1_5_39974': [],
#  'OG1_5_36356': ['Multiple classes'],
#  'OG1_5_36357': [],
#  'OG1_5_40764': [],
#  'OG1_5_47529': [],
#  'OG1_5_40765': ['Function unknown'],
#  'OG1_5_47528': ['General function prediction only'],
#  'OG1_5_38772': ['General function prediction only'],
#  'OG1_5_26711': [],
#  'OG1_5_26710': [],
#  'OG1_5_26713': [],
#  'OG1_5_26712': [],
#  'OG1_5_26715': [],
#  'OG1_5_26714': [],
#  'OG1_5_26717': [],
#  'OG1_5_26716': ['Lipid transport and metabolism'],
#  'OG1_5_26719': [],
#  'OG1_5_26718': [],
#  'OG1_5_40763': [],
#  'OG1_5_48571': [],
#  'OG1_5_38773': ['Cytoskeleton'],
#  'OG1_5_47521': [],
#  'OG1_5_47386': [],
#  'OG1_5_48573': [],
#  'OG1_5_38967': ['Transcription'],
#  'OG1_5_47384': [],
#  'OG1_5_47383': ['Extracellular structures'],
#  'OG1_5_48574': [],
#  'OG1_5_47381': [],
#  'OG1_5_47380': [],
#  'OG1_5_44548': [],
#  'OG1_5_44549': [],
#  'OG1_5_38407': ['General function prediction only'],
#  'OG1_5_44540': [],
#  'OG1_5_44541': [],
#  'OG1_5_44542': [],
#  'OG1_5_44543': [],
#  'OG1_5_44544': [],
#  'OG1_5_44545': [],
#  'OG1_5_44546': [],
#  'OG1_5_44547': [],
#  'OG1_5_38400': [],
#  'OG1_5_38401': [],
#  'OG1_5_38408': [],
#  'OG1_5_38409': ['General function prediction only'],
#  'OG1_5_48319': [],
#  'OG1_5_48318': [],
#  'OG1_5_33911': [],
#  'OG1_5_47169': [],
#  'OG1_5_47168': [],
#  'OG1_5_47167': [],
#  'OG1_5_47166': [],
#  'OG1_5_48313': [],
#  'OG1_5_47164': [],
#  'OG1_5_47163': [],
#  'OG1_5_48314': [],
#  'OG1_5_47161': ['Signal transduction mechanisms'],
#  'OG1_5_47160': [],
#  'OG1_5_30175': [],
#  'OG1_5_29560': ['Lipid transport and metabolism'],
#  'OG1_5_33910': [],
#  'OG1_5_38779': [],
#  'OG1_5_48452': [],
#  'OG1_5_36422': ['Signal transduction mechanisms'],
#  'OG1_5_36423': [],
#  'OG1_5_36420': ['Energy production and conversion'],
#  'OG1_5_36421': ['Signal transduction mechanisms'],
#  'OG1_5_36426': [],
#  'OG1_5_36427': [],
#  'OG1_5_36424': ['General function prediction only'],
#  'OG1_5_36425': ['Posttranslational modification, protein turnover, chaperones'],
#  'OG1_5_36428': [],
#  'OG1_5_36429': [],
#  'OG1_5_48453': [],
#  'OG1_5_8281': [],
#  'OG1_5_53863': [],
#  'OG1_5_53862': [],
#  'OG1_5_53861': [],
#  'OG1_5_53860': [],
#  'OG1_5_53867': [],
#  'OG1_5_53866': [],
#  'OG1_5_53865': [],
#  'OG1_5_53864': ['Multiple classes'],
#  'OG1_5_53869': [],
#  'OG1_5_53868': [],
#  'OG1_5_43827': [],
#  'OG1_5_43099': ['Function unknown'],
#  'OG1_5_43098': [],
#  'OG1_5_43093': [],
#  'OG1_5_43092': [],
#  'OG1_5_43091': [],
#  'OG1_5_43090': [],
#  'OG1_5_43097': [],
#  'OG1_5_43096': ['Multiple classes'],
#  'OG1_5_43095': [],
#  'OG1_5_43094': [],
#  'OG1_5_12366': [],
#  'OG1_5_40678': ['Multiple classes'],
#  'OG1_5_40679': ['Posttranslational modification, protein turnover, chaperones'],
#  'OG1_5_40676': [],
#  'OG1_5_40677': ['RNA processing and modification'],
#  'OG1_5_40674': [],
#  'OG1_5_40675': [],
#  'OG1_5_40672': [],
#  'OG1_5_40673': ['Posttranslational modification, protein turnover, chaperones'],
#  'OG1_5_40670': [],
#  'OG1_5_40671': [],
#  'OG1_5_43329': ['Function unknown'],
#  'OG1_5_43328': [],
#  'OG1_5_43325': [],
#  'OG1_5_43324': [],
#  'OG1_5_43327': [],
#  'OG1_5_43326': [],
#  'OG1_5_43321': [],
#  'OG1_5_43320': ['Function unknown'],
#  'OG1_5_43323': [],
#  'OG1_5_43322': ['Transcription'],
#  'OG1_5_46780': [],
#  'OG1_5_46781': [],
#  'OG1_5_46782': [],
#  'OG1_5_46783': [],
#  'OG1_5_46784': ['Multiple classes'],
#  'OG1_5_46785': [],
#  'OG1_5_46786': [],
#  'OG1_5_46787': [],
#  'OG1_5_46788': [],
#  'OG1_5_46789': [],
#  'OG1_5_33812': [],
#  'OG1_5_29927': [],
#  'OG1_5_29926': [],
#  'OG1_5_29925': [],
#  'OG1_5_29924': [],
#  'OG1_5_29923': [],
#  'OG1_5_29922': [],
#  'OG1_5_29921': ['Multiple classes'],
#  'OG1_5_29920': [],
#  'OG1_5_24086': [],
#  'OG1_5_29929': [],
#  'OG1_5_29928': ['Coenzyme transport and metabolism'],
#  'OG1_5_28038': [],
#  'OG1_5_28039': [],
#  'OG1_5_28032': [],
#  'OG1_5_28033': [],
#  'OG1_5_28030': [],
#  'OG1_5_28031': [],
#  'OG1_5_28036': ['Transcription'],
#  'OG1_5_28037': [],
#  'OG1_5_28034': [],
#  'OG1_5_28035': [],
#  'OG1_5_52099': [],
#  'OG1_5_52098': [],
#  'OG1_5_41789': [],
#  'OG1_5_41788': [],
#  'OG1_5_52091': [],
#  'OG1_5_52090': ['Nucleotide transport and metabolism'],
#  'OG1_5_52093': ['RNA processing and modification'],
#  'OG1_5_52092': [],
#  'OG1_5_52095': [],
#  'OG1_5_52094': [],
#  'OG1_5_52097': ['General function prediction only'],
#  'OG1_5_52096': [],
#  'OG1_5_11959': [],
#  'OG1_5_11958': [],
#  'OG1_5_14709': ['RNA processing and modification'],
#  'OG1_5_14708': ['Multiple classes'],
#  'OG1_5_14703': [],
#  'OG1_5_14702': [],
#  'OG1_5_11953': ['Cytoskeleton'],
#  'OG1_5_11952': ['Function unknown', 'Cell wall/membrane/envelope biogenesis'],
#  'OG1_5_14707': [],
#  'OG1_5_14706': [],
#  'OG1_5_14705': [],
#  'OG1_5_11956': ['Transcription'],
#  'OG1_5_27376': [],
#  'OG1_5_16639': [],
#  'OG1_5_16638': ['Carbohydrate transport and metabolism'],
#  'OG1_5_16635': [],
#  'OG1_5_16634': [],
#  'OG1_5_16637': [],
#  'OG1_5_16636': [],
#  'OG1_5_16631': ['Cytoskeleton'],
#  'OG1_5_16630': [],
#  'OG1_5_16633': [],
#  'OG1_5_16632': [],
#  'OG1_5_41257': ['Multiple classes'],
#  'OG1_5_57570': [],
#  'OG1_5_57573': [],
#  'OG1_5_57572': [],
#  'OG1_5_57575': [],
#  'OG1_5_4838': ['Cytoskeleton'],
#  'OG1_5_57577': [],
#  'OG1_5_57576': [],
#  'OG1_5_57579': ['Coenzyme transport and metabolism'],
#  'OG1_5_4834': ['Intracellular trafficking, secretion, and vesicular transport'],
#  'OG1_5_4837': ['Transcription'],
#  'OG1_5_4836': [],
#  'OG1_5_4831': ['General function prediction only',
#   'Amino acid transport and metabolism'],
#  'OG1_5_4830': ['Translation, ribosomal structure and biogenesis'],
#  'OG1_5_4833': [],
#  'OG1_5_4832': [],
#  'OG1_5_15519': [],
#  'OG1_5_15518': [],
#  'OG1_5_15515': ['Chromatin structure and dynamics'],
#  'OG1_5_15514': [],
#  'OG1_5_15517': ['Function unknown'],
#  'OG1_5_34866': [],
#  'OG1_5_5026': [],
#  'OG1_5_47958': [],
#  'OG1_5_47959': ['Coenzyme transport and metabolism'],
#  'OG1_5_47956': [],
#  'OG1_5_47957': [],
#  'OG1_5_47954': [],
#  'OG1_5_47955': [],
#  'OG1_5_47952': [],
#  'OG1_5_47953': [],
#  'OG1_5_47950': [],
#  'OG1_5_47951': [],
#  'OG1_5_15513': [],
#  'OG1_5_15512': ['Intracellular trafficking, secretion, and vesicular transport'],
#  'OG1_5_4772': [],
#  'OG1_5_23978': [],
#  'OG1_5_23979': ['Carbohydrate transport and metabolism'],
#  'OG1_5_23976': [],
#  'OG1_5_23977': [],
#  'OG1_5_23974': [],
#  'OG1_5_23975': ['Cytoskeleton'],
#  'OG1_5_23972': [],
#  'OG1_5_23973': [],
#  'OG1_5_23970': [],
#  'OG1_5_23971': [],
#  'OG1_5_18003': [],
#  'OG1_5_18149': ['Posttranslational modification, protein turnover, chaperones',
#   'Multiple classes'],
#  'OG1_5_18148': [],
#  'OG1_5_18145': ['Posttranslational modification, protein turnover, chaperones'],
#  'OG1_5_18144': ['Multiple classes'],
#  'OG1_5_18147': [],
#  'OG1_5_18146': [],
#  'OG1_5_18141': [],
#  'OG1_5_18140': ['Coenzyme transport and metabolism'],
#  'OG1_5_18143': [],
#  'OG1_5_18142': ['Multiple classes',
#   'Translation, ribosomal structure and biogenesis'],
#  'OG1_5_10772': [],
#  'OG1_5_10773': ['Multiple classes', 'Signal transduction mechanisms'],
#  'OG1_5_10770': ['Translation, ribosomal structure and biogenesis'],
#  'OG1_5_10771': [],
#  'OG1_5_10776': ['Inorganic ion transport and metabolism'],
#  'OG1_5_10777': ['Amino acid transport and metabolism'],
#  'OG1_5_10774': ['Coenzyme transport and metabolism'],
#  'OG1_5_10775': ['Multiple classes'],
#  'OG1_5_10778': ['General function prediction only'],
#  'OG1_5_10779': [],
#  'OG1_5_53052': [],
#  'OG1_5_53053': [],
#  'OG1_5_53050': [],
#  'OG1_5_53051': [],
#  'OG1_5_53056': [],
#  'OG1_5_53057': [],
#  'OG1_5_53054': ['Multiple classes'],
#  'OG1_5_53055': [],
#  'OG1_5_54008': [],
#  'OG1_5_54009': [],
#  'OG1_5_53058': [],
#  'OG1_5_53059': [],
#  'OG1_5_2932': ['Multiple classes'],
#  'OG1_5_2933': ['Coenzyme transport and metabolism'],
#  'OG1_5_2930': [],
#  'OG1_5_2931': ['Cytoskeleton'],
#  'OG1_5_2936': ['RNA processing and modification', 'Cytoskeleton'],
#  'OG1_5_2937': ['Posttranslational modification, protein turnover, chaperones'],
#  'OG1_5_2934': ['Multiple classes',
#   'Intracellular trafficking, secretion, and vesicular transport'],
#  'OG1_5_2935': ['Energy production and conversion'],
#  'OG1_5_56712': [],
#  'OG1_5_56713': [],
#  'OG1_5_2938': ['Lipid transport and metabolism',
#   'Replication, recombination and repair'],
#  'OG1_5_2939': ['General function prediction only'],
#  'OG1_5_56716': [],
#  'OG1_5_56717': [],
#  'OG1_5_56714': [],
#  'OG1_5_56715': [],
#  'OG1_5_4303': ['Cell wall/membrane/envelope biogenesis'],
#  'OG1_5_4302': ['Signal transduction mechanisms', 'Multiple classes'],
#  'OG1_5_4301': [],
#  'OG1_5_4300': ['Posttranslational modification, protein turnover, chaperones'],
#  'OG1_5_4307': ['Intracellular trafficking, secretion, and vesicular transport'],
#  'OG1_5_4306': ['Cytoskeleton'],
#  'OG1_5_4305': ['Transcription',
#   'Signal transduction mechanisms',
#   'Multiple classes'],
#  'OG1_5_4304': ['Transcription',
#   'Intracellular trafficking, secretion, and vesicular transport'],
#  'OG1_5_22593': [],
#  'OG1_5_22592': [],
#  'OG1_5_4309': ['Defense mechanisms'],
#  'OG1_5_4308': ['Energy production and conversion'],
#  'OG1_5_22597': [],
#  'OG1_5_22596': [],
#  'OG1_5_22595': [],
#  'OG1_5_22594': [],
#  'OG1_5_2684': ['Multiple classes',
#   'Intracellular trafficking, secretion, and vesicular transport'],
#  'OG1_5_2685': ['Signal transduction mechanisms', 'Multiple classes'],
#  'OG1_5_2686': ['Translation, ribosomal structure and biogenesis',
#   'Multiple classes'],
#  'OG1_5_2687': [],
#  'OG1_5_2680': ['Lipid transport and metabolism'],
#  'OG1_5_20998': ['Translation, ribosomal structure and biogenesis'],
#  'OG1_5_2682': ['Multiple classes'],
#  'OG1_5_2683': ['General function prediction only'],
#  'OG1_5_20995': [],
#  'OG1_5_20994': [],
#  'OG1_5_20997': [],
#  'OG1_5_20996': ['Lipid transport and metabolism'],
#  'OG1_5_2688': ['Multiple classes', 'Transcription'],
#  'OG1_5_2689': [],
#  'OG1_5_20993': [],
#  'OG1_5_20992': [],
#  'OG1_5_50651': [],
#  'OG1_5_50650': [],
#  'OG1_5_50653': [],
#  'OG1_5_50652': [],
#  'OG1_5_50655': [],
#  'OG1_5_50654': [],
#  'OG1_5_50657': [],
#  'OG1_5_50656': [],
#  'OG1_5_50659': ['Nucleotide transport and metabolism'],
#  'OG1_5_22624': ['Intracellular trafficking, secretion, and vesicular transport'],
#  'OG1_5_22627': ['Multiple classes'],
#  'OG1_5_22626': ['Lipid transport and metabolism'],
#  'OG1_5_22621': [],
#  'OG1_5_22620': ['Multiple classes', 'Cytoskeleton'],
#  'OG1_5_22623': [],
#  'OG1_5_22622': ['Translation, ribosomal structure and biogenesis'],
#  'OG1_5_3089': ['General function prediction only', 'Transcription'],
#  'OG1_5_3088': ['Function unknown'],
#  'OG1_5_3081': [],
#  'OG1_5_3080': ['Replication, recombination and repair'],
#  'OG1_5_3083': [],
#  'OG1_5_3082': ['Carbohydrate transport and metabolism'],
#  'OG1_5_3085': [],
#  'OG1_5_3084': [],
#  'OG1_5_3087': [],
#  'OG1_5_3086': ['Translation, ribosomal structure and biogenesis'],
#  'OG1_5_43233': [],
#  'OG1_5_43232': [],
#  'OG1_5_20667': [],
#  'OG1_5_20666': [],
#  'OG1_5_20665': ['Extracellular structures'],
#  'OG1_5_20664': ['Multiple classes'],
#  'OG1_5_20663': ['Secondary metabolites biosynthesis, transport and catabolism'],
#  'OG1_5_20662': [],
#  'OG1_5_20661': [],
#  'OG1_5_20660': [],
#  'OG1_5_41462': [],
#  'OG1_5_20669': ['Cytoskeleton'],
#  'OG1_5_20668': ['Transcription'],
#  'OG1_5_52879': [],
#  'OG1_5_52878': [],
#  'OG1_5_25019': [],
#  'OG1_5_25018': [],
#  'OG1_5_52873': [],
#  'OG1_5_52872': [],
#  'OG1_5_52871': [],
#  'OG1_5_52870': ['Transcription'],
#  'OG1_5_52877': [],
#  'OG1_5_52876': [],
#  'OG1_5_52875': [],
#  'OG1_5_52874': [],
#  'OG1_5_3333': [],
#  'OG1_5_3332': ['Carbohydrate transport and metabolism'],
#  'OG1_5_3331': ['Posttranslational modification, protein turnover, chaperones'],
#  'OG1_5_3330': ['Posttranslational modification, protein turnover, chaperones'],
#  'OG1_5_3337': ['Cytoskeleton'],
#  'OG1_5_3336': ['Intracellular trafficking, secretion, and vesicular transport',
#   'RNA processing and modification',
#   'Multiple classes'],
#  'OG1_5_3335': [],
#  'OG1_5_3334': ['RNA processing and modification'],
#  'OG1_5_3339': [],
#  'OG1_5_3338': ['Posttranslational modification, protein turnover, chaperones'],
#  'OG1_5_8488': ['General function prediction only',
#   'RNA processing and modification'],
#  'OG1_5_13949': [],
#  'OG1_5_55061': [],
#  'OG1_5_8481': [],
#  'OG1_5_8482': ['Defense mechanisms',
#   'Posttranslational modification, protein turnover, chaperones'],
#  'OG1_5_8483': ['Translation, ribosomal structure and biogenesis'],
#  'OG1_5_8484': ['General function prediction only'],
#  'OG1_5_8485': [],
#  'OG1_5_55067': [],
#  'OG1_5_8487': ['Coenzyme transport and metabolism'],
#  'OG1_5_33310': [],
#  'OG1_5_46692': ['Cell cycle control, cell division, chromosome partitioning'],
#  'OG1_5_34991': ['Transcription'],
#  'OG1_5_46693': [],
#  'OG1_5_41549': [],
#  'OG1_5_51520': [],
#  'OG1_5_51521': [],
#  'OG1_5_51522': [],
#  'OG1_5_51523': [],
#  'OG1_5_6309': ['Posttranslational modification, protein turnover, chaperones',
#   'Chromatin structure and dynamics',
#   'Transcription'],
#  'OG1_5_51525': [],
#  'OG1_5_51526': [],
#  'OG1_5_51527': [],
#  'OG1_5_51528': [],
#  'OG1_5_51529': [],
#  'OG1_5_6307': [],
#  'OG1_5_6306': [],
#  'OG1_5_6301': ['General function prediction only'],
#  'OG1_5_6300': [],
#  'OG1_5_6303': ['RNA processing and modification',
#   'Lipid transport and metabolism',
#   'General function prediction only'],
#  'OG1_5_6302': ['Carbohydrate transport and metabolism'],
#  'OG1_5_5970': [],
#  'OG1_5_54375': ['Signal transduction mechanisms'],
#  'OG1_5_1296': ['Inorganic ion transport and metabolism'],
#  'OG1_5_1297': ['General function prediction only'],
#  'OG1_5_34752': [],
#  'OG1_5_31501': [],
#  'OG1_5_34750': [],
#  'OG1_5_34751': [],
#  'OG1_5_31504': [],
#  'OG1_5_31505': [],
#  'OG1_5_31506': [],
#  'OG1_5_31507': [],
#  'OG1_5_31508': [],
#  'OG1_5_31509': [],
#  'OG1_5_34758': [],
#  'OG1_5_34759': [],
#  'OG1_5_41827': [],
#  'OG1_5_5979': ['Lipid transport and metabolism'],
#  'OG1_5_1299': [],
#  'OG1_5_9076': [],
#  'OG1_5_25909': [],
#  'OG1_5_25908': [],
#  'OG1_5_9077': ['Cytoskeleton', 'Transcription'],
#  'OG1_5_25905': [],
#  'OG1_5_25904': [],
#  'OG1_5_25907': [],
#  'OG1_5_25906': [],
#  'OG1_5_25901': [],
#  'OG1_5_25900': [],
#  'OG1_5_25903': ['Transcription'],
#  'OG1_5_25902': ['Energy production and conversion'],
#  'OG1_5_40033': ['Inorganic ion transport and metabolism'],
#  'OG1_5_54822': [],
#  'OG1_5_54823': [],
#  'OG1_5_54820': [],
#  'OG1_5_54821': [],
#  'OG1_5_54826': [],
#  'OG1_5_54827': [],
#  'OG1_5_54824': [],
#  'OG1_5_54825': ['Energy production and conversion'],
#  'OG1_5_54828': [],
#  'OG1_5_54829': [],
#  'OG1_5_34215': [],
#  'OG1_5_1652': [],
#  'OG1_5_1653': ['Energy production and conversion'],
#  'OG1_5_1650': ['RNA processing and modification',
#   'Multiple classes',
#   'General function prediction only'],
#  'OG1_5_1651': ['Carbohydrate transport and metabolism', 'Function unknown'],
#  'OG1_5_1656': [],
#  'OG1_5_1657': ['RNA processing and modification'],
#  'OG1_5_1654': ['Translation, ribosomal structure and biogenesis'],
#  'OG1_5_1655': ['Lipid transport and metabolism'],
#  'OG1_5_34213': [],
#  'OG1_5_1658': [],
#  'OG1_5_1659': ['Inorganic ion transport and metabolism'],
#  'OG1_5_34212': [],
#  'OG1_5_34211': ['Posttranslational modification, protein turnover, chaperones'],
#  'OG1_5_12032': [],
#  'OG1_5_34210': ['General function prediction only'],
#  'OG1_5_9078': [],
#  'OG1_5_9079': [],
#  'OG1_5_33908': [],
#  'OG1_5_33909': [],
#  'OG1_5_33902': [],
#  'OG1_5_33903': [],
#  'OG1_5_33900': [],
#  'OG1_5_33901': [],
#  'OG1_5_33906': [],
#  'OG1_5_33907': [],
#  'OG1_5_33904': ['Transcription'],
#  'OG1_5_33905': [],
#  'OG1_5_5825': ['Posttranslational modification, protein turnover, chaperones'],
#  'OG1_5_5824': ['Multiple classes'],
#  'OG1_5_5827': [],
#  'OG1_5_5826': ['General function prediction only'],
#  'OG1_5_5821': ['Intracellular trafficking, secretion, and vesicular transport'],
#  'OG1_5_5820': ['General function prediction only'],
#  'OG1_5_5823': ['Posttranslational modification, protein turnover, chaperones'],
#  'OG1_5_5822': ['Nucleotide transport and metabolism'],
#  'OG1_5_5829': ['Function unknown'],
#  'OG1_5_5828': ['Posttranslational modification, protein turnover, chaperones'],
#  'OG1_5_32369': [],
#  'OG1_5_32368': [],
#  'OG1_5_32361': [],
#  'OG1_5_32360': ['General function prediction only'],
#  'OG1_5_32363': [],
#  'OG1_5_32362': [],
#  'OG1_5_32365': ['Function unknown'],
#  'OG1_5_32364': [],
#  'OG1_5_32367': [],
#  'OG1_5_32366': [],
#  'OG1_5_48718': [],
#  'OG1_5_4615': ['Energy production and conversion'],
#  'OG1_5_22535': [],
#  'OG1_5_41540': [],
#  'OG1_5_13924': ['Function unknown'],
#  'OG1_5_23507': [],
#  'OG1_5_23506': [],
#  'OG1_5_23505': [],
#  'OG1_5_23504': [],
#  'OG1_5_23503': [],
#  'OG1_5_23502': [],
#  'OG1_5_23501': [],
#  'OG1_5_23500': [],
#  'OG1_5_23509': [],
#  'OG1_5_23508': [],
#  'OG1_5_49002': [],
#  'OG1_5_49003': [],
#  'OG1_5_49000': [],
#  'OG1_5_49001': [],
#  'OG1_5_49006': [],
#  'OG1_5_49007': [],
#  'OG1_5_49004': [],
#  'OG1_5_49005': [],
#  'OG1_5_49008': [],
#  'OG1_5_49009': [],
#  'OG1_5_57038': [],
#  'OG1_5_57039': ['Multiple classes'],
#  'OG1_5_18800': [],
#  'OG1_5_18801': [],
#  'OG1_5_18802': [],
#  'OG1_5_18803': ['Transcription'],
#  'OG1_5_18804': [],
#  'OG1_5_18805': ['Signal transduction mechanisms'],
#  'OG1_5_18806': [],
#  'OG1_5_18807': [],
#  'OG1_5_12846': ['General function prediction only',
#   'Function unknown',
#   'Chromatin structure and dynamics'],
#  'OG1_5_12847': [],
#  'OG1_5_12844': ['RNA processing and modification', 'Multiple classes'],
#  'OG1_5_12845': ['Coenzyme transport and metabolism'],
#  'OG1_5_12842': [],
#  'OG1_5_12843': [],
#  'OG1_5_12840': ['Signal transduction mechanisms'],
#  'OG1_5_12841': [],
#  'OG1_5_12848': ['Translation, ribosomal structure and biogenesis'],
#  'OG1_5_12849': ['RNA processing and modification',
#   'Posttranslational modification, protein turnover, chaperones'],
#  'OG1_5_33018': [],
#  'OG1_5_33019': [],
#  'OG1_5_33010': [],
#  'OG1_5_33011': [],
#  'OG1_5_33012': [],
#  'OG1_5_33013': [],
#  'OG1_5_33014': ['Carbohydrate transport and metabolism'],
#  'OG1_5_33015': [],
#  'OG1_5_33016': [],
#  'OG1_5_33017': [],
#  'OG1_5_36620': ['Intracellular trafficking, secretion, and vesicular transport'],
#  'OG1_5_36621': ['Multiple classes'],
#  'OG1_5_36622': ['Inorganic ion transport and metabolism'],
#  'OG1_5_36623': [],
#  'OG1_5_36624': ['Lipid transport and metabolism'],
#  'OG1_5_36625': [],
#  'OG1_5_36626': [],
#  'OG1_5_36627': [],
#  'OG1_5_36628': ['Chromatin structure and dynamics'],
#  'OG1_5_36629': [],
#  'OG1_5_48661': [],
#  'OG1_5_48660': [],
#  'OG1_5_48663': [],
#  'OG1_5_48662': [],
#  'OG1_5_48665': ['Carbohydrate transport and metabolism'],
#  'OG1_5_48664': [],
#  'OG1_5_48667': ['Signal transduction mechanisms'],
#  'OG1_5_48666': [],
#  'OG1_5_48669': [],
#  'OG1_5_48668': [],
#  'OG1_5_23314': [],
#  'OG1_5_44171': [],
#  'OG1_5_44170': [],
#  'OG1_5_44173': [],
#  'OG1_5_44172': [],
#  'OG1_5_44175': [],
#  'OG1_5_44174': [],
#  'OG1_5_44177': [],
#  'OG1_5_44176': [],
#  'OG1_5_44179': ['Function unknown'],
#  'OG1_5_44178': [],
#  'OG1_5_30660': [],
#  'OG1_5_30661': [],
#  'OG1_5_30666': [],
#  'OG1_5_30667': [],
#  'OG1_5_30664': ['Posttranslational modification, protein turnover, chaperones'],
#  'OG1_5_30665': ['Multiple classes'],
#  'OG1_5_36998': [],
#  'OG1_5_36999': [],
#  'OG1_5_28126': [],
#  'OG1_5_36992': [],
#  'OG1_5_36993': [],
#  'OG1_5_36990': [],
#  'OG1_5_36991': [],
#  'OG1_5_36996': [],
#  'OG1_5_36997': [],
#  'OG1_5_36994': ['Chromatin structure and dynamics'],
#  'OG1_5_36995': ['Posttranslational modification, protein turnover, chaperones'],
#  'OG1_5_2371': ['Translation, ribosomal structure and biogenesis'],
#  'OG1_5_30598': [],
#  'OG1_5_30599': ['General function prediction only'],
#  'OG1_5_30594': ['Secondary metabolites biosynthesis, transport and catabolism'],
#  'OG1_5_30595': ['Carbohydrate transport and metabolism'],
#  'OG1_5_30596': [],
#  'OG1_5_30597': ['Multiple classes'],
#  'OG1_5_30590': [],
#  'OG1_5_30591': [],
#  'OG1_5_30592': [],
#  'OG1_5_30593': [],
#  'OG1_5_15018': ['RNA processing and modification'],
#  'OG1_5_15019': [],
#  'OG1_5_15014': ['Function unknown'],
#  'OG1_5_15015': ['Cytoskeleton'],
#  'OG1_5_15016': [],
#  'OG1_5_15017': [],
#  'OG1_5_15010': ['Posttranslational modification, protein turnover, chaperones'],
#  'OG1_5_15011': ['Intracellular trafficking, secretion, and vesicular transport'],
#  'OG1_5_15012': ['RNA processing and modification',
#   'Replication, recombination and repair'],
#  'OG1_5_15013': ['Transcription'],
#  'OG1_5_42436': ['Multiple classes'],
#  'OG1_5_42437': [],
#  'OG1_5_42434': [],
#  'OG1_5_42435': [],
#  'OG1_5_42432': [],
#  'OG1_5_42433': ['Posttranslational modification, protein turnover, chaperones'],
#  'OG1_5_42430': [],
#  'OG1_5_42431': [],
#  'OG1_5_42438': [],
#  'OG1_5_42439': [],
#  'OG1_5_11524': [],
#  'OG1_5_11525': [],
#  'OG1_5_55478': [],
#  'OG1_5_16433': ['Multiple classes'],
#  'OG1_5_16432': [],
#  'OG1_5_16431': ['Multiple classes'],
#  'OG1_5_16430': [],
#  'OG1_5_16437': ['Multiple classes'],
#  'OG1_5_16436': [],
#  'OG1_5_16435': [],
#  'OG1_5_16434': ['Posttranslational modification, protein turnover, chaperones'],
#  'OG1_5_26481': [],
#  'OG1_5_16439': [],
#  'OG1_5_16438': [],
#  'OG1_5_11521': ['Posttranslational modification, protein turnover, chaperones'],
#  'OG1_5_12543': [],
#  'OG1_5_12542': [],
#  'OG1_5_12541': [],
#  'OG1_5_12540': [],
#  'OG1_5_12547': [],
#  'OG1_5_12546': [],
#  'OG1_5_12545': ['Posttranslational modification, protein turnover, chaperones'],
#  'OG1_5_12544': ['General function prediction only'],
#  'OG1_5_12549': ['Function unknown'],
#  'OG1_5_12548': [],
#  'OG1_5_17526': ['General function prediction only'],
#  'OG1_5_17527': ['Transcription'],
#  'OG1_5_17524': ['General function prediction only'],
#  'OG1_5_17525': [],
#  'OG1_5_17522': ['Replication, recombination and repair',
#   'Chromatin structure and dynamics'],
#  'OG1_5_17523': [],
#  'OG1_5_17520': [],
#  'OG1_5_17521': [],
#  'OG1_5_44867': ['Multiple classes'],
#  'OG1_5_17528': ['Cell wall/membrane/envelope biogenesis'],
#  'OG1_5_17529': [],
#  'OG1_5_14875': [],
#  'OG1_5_14874': ['Energy production and conversion'],
#  'OG1_5_14877': ['Multiple classes'],
#  'OG1_5_14876': ['RNA processing and modification'],
#  'OG1_5_14871': [],
#  'OG1_5_14870': [],
#  'OG1_5_14873': ['Secondary metabolites biosynthesis, transport and catabolism'],
#  'OG1_5_14872': ['Intracellular trafficking, secretion, and vesicular transport'],
#  'OG1_5_11528': [],
#  'OG1_5_14879': [],
#  'OG1_5_14878': [],
#  'OG1_5_55477': [],
#  'OG1_5_16143': ['Extracellular structures', 'Function unknown'],
#  'OG1_5_16142': [],
#  'OG1_5_16141': ['Cytoskeleton'],
#  'OG1_5_9537': ['Transcription'],
#  'OG1_5_12094': [],
#  'OG1_5_9535': ['Transcription',
#   'Intracellular trafficking, secretion, and vesicular transport'],
#  'OG1_5_9534': [],
#  'OG1_5_12091': ['Posttranslational modification, protein turnover, chaperones'],
#  'OG1_5_12090': ['Translation, ribosomal structure and biogenesis'],
#  'OG1_5_12093': ['Energy production and conversion', 'Transcription'],
#  'OG1_5_9530': ['Multiple classes',
#   'Cell cycle control, cell division, chromosome partitioning'],
#  'OG1_5_16147': [],
#  'OG1_5_12099': ['Replication, recombination and repair'],
#  'OG1_5_12098': ['Posttranslational modification, protein turnover, chaperones'],
#  'OG1_5_9539': ['Signal transduction mechanisms'],
#  'OG1_5_9538': ['Multiple classes', 'Transcription'],
#  'OG1_5_16145': [],
#  'OG1_5_16144': [],
#  'OG1_5_44993': [],
#  'OG1_5_44992': [],
#  'OG1_5_44991': [],
#  'OG1_5_44990': ['Inorganic ion transport and metabolism'],
#  'OG1_5_44997': [],
#  'OG1_5_44996': [],
#  'OG1_5_44995': [],
#  'OG1_5_44994': [],
#  'OG1_5_44999': [],
#  'OG1_5_44998': ['Translation, ribosomal structure and biogenesis'],
#  'OG1_5_41316': [],
#  'OG1_5_41317': ['Replication, recombination and repair'],
#  'OG1_5_41314': [],
#  'OG1_5_41315': ['Lipid transport and metabolism'],
#  'OG1_5_41312': [],
#  'OG1_5_41313': ['Posttranslational modification, protein turnover, chaperones'],
#  'OG1_5_41310': [],
#  'OG1_5_41311': [],
#  'OG1_5_10964': ['Signal transduction mechanisms'],
#  'OG1_5_41318': ['Signal transduction mechanisms'],
#  'OG1_5_41319': ['General function prediction only'],
#  'OG1_5_27671': ['General function prediction only'],
#  'OG1_5_27670': [],
#  'OG1_5_27673': [],
#  'OG1_5_17381': ['Posttranslational modification, protein turnover, chaperones'],
#  'OG1_5_17386': [],
#  'OG1_5_17387': ['Multiple classes'],
#  'OG1_5_17384': [],
#  'OG1_5_27676': [],
#  'OG1_5_27679': ['Translation, ribosomal structure and biogenesis',
#   'Lipid transport and metabolism'],
#  'OG1_5_27678': [],
#  'OG1_5_17388': [],
#  'OG1_5_17389': [],
#  'OG1_5_41565': ['Transcription'],
#  'OG1_5_41564': ['Amino acid transport and metabolism'],
#  'OG1_5_41567': [],
#  'OG1_5_41566': ['Multiple classes'],
#  'OG1_5_56175': [],
#  'OG1_5_41561': [],
#  'OG1_5_41560': [],
#  'OG1_5_41563': [],
#  'OG1_5_41562': [],
#  'OG1_5_46843': [],
#  'OG1_5_46842': ['Lipid transport and metabolism'],
#  'OG1_5_46841': [],
#  'OG1_5_46840': [],
#  'OG1_5_46847': [],
#  'OG1_5_46846': [],
#  'OG1_5_46845': [],
#  'OG1_5_46844': [],
#  'OG1_5_46849': ['Signal transduction mechanisms'],
#  'OG1_5_46848': ['Replication, recombination and repair'],
#  'OG1_5_38499': ['Signal transduction mechanisms'],
#  'OG1_5_15838': [],
#  'OG1_5_15839': [],
#  'OG1_5_15836': [],
#  'OG1_5_15837': ['Posttranslational modification, protein turnover, chaperones'],
#  'OG1_5_15834': [],
#  'OG1_5_15835': [],
#  'OG1_5_15832': ['Inorganic ion transport and metabolism'],
#  'OG1_5_15833': [],
#  'OG1_5_15830': [],
#  'OG1_5_15831': ['Multiple classes'],
#  'OG1_5_47376': [],
#  'OG1_5_39972': [],
#  'OG1_5_23389': [],
#  'OG1_5_47377': [],
#  'OG1_5_38639': [],
#  'OG1_5_38638': ['General function prediction only'],
#  'OG1_5_21736': [],
#  'OG1_5_26101': [],
#  'OG1_5_26102': [],
#  'OG1_5_21735': [],
#  'OG1_5_26104': ['Secondary metabolites biosynthesis, transport and catabolism'],
#  'OG1_5_21733': [],
#  'OG1_5_26106': [],
#  'OG1_5_26107': ['Cytoskeleton'],
#  'OG1_5_26108': ['Energy production and conversion'],
#  'OG1_5_26109': [],
#  'OG1_5_38493': [],
#  'OG1_5_21738': [],
#  'OG1_5_21739': ['Function unknown'],
#  'OG1_5_20465': [],
#  'OG1_5_41865': [],
#  'OG1_5_20467': [],
#  'OG1_5_20466': ['Intracellular trafficking, secretion, and vesicular transport'],
#  'OG1_5_41860': [],
#  'OG1_5_41861': ['Transcription'],
#  'OG1_5_20463': [],
#  'OG1_5_20462': [],
#  'OG1_5_28612': [],
#  'OG1_5_28613': [],
#  ...}

# %%
def Create_Hash_KogFiles(fileHash):
    translated={}
    for i,key in enumerate(Genes_Uniq_Venn.keys()):
        translated[key]=str(key)

    xs=translated.values()
    xs.sort()
    xs.sort(key = lambda s: len(s), reverse=True)
    xs
    s=set()
    for line in open('KOG/output/output.2.class'):
        l=line.split('\t')
        s.add(l[2].strip())
    s.add('Unannotated')
    s.remove('description')
    s.add('Multiple classes')
    outHash={}       
    for sample in TPM_Hash:
        Sample_TPM=TPM_Hash[sample]
        Kegg_DF_CoreGenes=pd.DataFrame(index=s, columns=xs)
        Kegg_DF_CoreGenes=Kegg_DF_CoreGenes.fillna(0)
        for setType in Genes_Uniq_Venn:
            a_setType=translated[setType]
            for OG in Genes_Uniq_Venn[setType]:
                totalTPM_OG=Sample_TPM.loc[OG,'TPM']
                if newOG_KOGHash[OG]==[]:
                    p='Unannotated'
                    Kegg_DF_CoreGenes.loc[p,a_setType]+=totalTPM_OG
                else:
                    num=len(newOG_KOGHash[OG])
                    for k in newOG_KOGHash[OG]:
                        p=k
                        Kegg_DF_CoreGenes.loc[p,a_setType]+=totalTPM_OG/num
        Kegg_DF_CoreGenes_Percentage=(Kegg_DF_CoreGenes.drop('Unannotated')/Kegg_DF_CoreGenes.drop('Unannotated').sum())
        outHash[sample+'_percentage']=Kegg_DF_CoreGenes_Percentage
        outHash[sample+'_raw']=Kegg_DF_CoreGenes
        Kegg_DF_CoreGenes.to_csv(sample+'_KOGModule_rawTPM.tab', sep='\t')
        Kegg_DF_CoreGenes_Percentage.to_csv(sample+'_KOGModule_percentage.tab', sep='\t')
    return outHash
        

def ParseField_RSEM_Files(files):
    InsituHash={}
    for f in glob.glob(files):
        name=f.split('/')[2]
        name=name.split('_')[0]
        
        InsituHash[name]=pd.read_table(f,index_col='gene_id')

    outHash={}
    for sample in InsituHash:
        a={}
        for group in Genes_Uniq_Venn:
            match=InsituHash[sample].loc[Genes_Uniq_Venn[group]].TPM
            summedTPM=InsituHash[sample].loc[Genes_Uniq_Venn[group]].TPM.sum()
            len_match=len(match)
            len_match_greater0=len(match[match>0])
            a[group]={}
            a[group]['TPM']=summedTPM
            a[group]['Len_total']=len_match
            a[group]['Greater0']=len_match_greater0
        outHash[sample]=a
    return InsituHash
        
TPM_Hash=ParseField_RSEM_Files('../output_RSEM_Bowtie2/*genes.results')


        
KOG_TPM_Hash=Create_Hash_KogFiles(TPM_Hash)
cpk.dump(KOG_TPM_Hash, open('KOG_TPM_Hash.pickle', 'w'))

#The above script can be used to generate the pickle and the original files/pickle.  But, it takes a long time to run... so just load it if you can

# KOG_TPM_Hash=cpk.load(open('KOG_TPM_Hash.pickle', 'r'))

# %%
keys=KOG_TPM_Hash.keys()
rawKeys = [s for s in keys if "raw" in s]
InsituKeys = [s for s in rawKeys if "Z" in s]
InsituKeys=sorted(InsituKeys)

fig,axs=plt.subplots(6)
fig.set_figheight(12)
fig.set_figwidth(8)
c=0
for keys,ax in zip(InsituKeys,axs):
    c+=1
    if c==1:
        k=KOG_TPM_Hash[keys].T.plot(kind='bar', cmap=ccmap, stacked=True, title=keys,ax=ax, grid=False)
#         k=KOG_TPM_Hash[keys].drop('Unannotated').T.plot(kind='bar', cmap=ccmap, stacked=True, title=keys,ax=ax, grid=False)
        k.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.,ncol=4)

    else: 
        KOG_TPM_Hash[keys].T.plot(kind='bar', cmap=ccmap, stacked=True, title=keys,ax=ax,grid=False, legend=False)

#         KOG_TPM_Hash[keys].drop('Unannotated').T.plot(kind='bar', cmap=ccmap, stacked=True, title=keys,ax=ax,grid=False, legend=False)
fig.savefig('Raw_Insitu_KOG.pdf')

# %%
keys=KOG_TPM_Hash.keys()
rawKeys = [s for s in keys if "raw" in s]
InsituKeys = [s for s in rawKeys if "1" in s]
InsituKeys=sorted(InsituKeys)

fig,axs=plt.subplots(6)
fig.set_figheight(12)
fig.set_figwidth(8)
c=0
for keys,ax in zip(InsituKeys,axs):
    c+=1
    if c==1:
        k=KOG_TPM_Hash[keys].drop('Unannotated').T.plot(kind='bar', cmap=ccmap, stacked=True, title=keys,ax=ax, grid=False)
        k.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.,ncol=4)

    else: 
        KOG_TPM_Hash[keys].drop('Unannotated').T.plot(kind='bar', cmap=ccmap, stacked=True, title=keys,ax=ax,grid=False, legend=False)
fig.savefig('Raw_E1_KOG.pdf')

# %%
keys=KOG_TPM_Hash.keys()
rawKeys = [s for s in keys if "percentage" in s]
InsituKeys = [s for s in rawKeys if "1" in s]
InsituKeys=sorted(InsituKeys)

fig,axs=plt.subplots(6)
fig.set_figheight(12)
fig.set_figwidth(8)
c=0
for keys,ax in zip(InsituKeys,axs):
    c+=1
    if c==1:
        k=KOG_TPM_Hash[keys].T.plot(kind='bar', cmap=ccmap, stacked=True, title=keys,ax=ax, grid=False)
        k.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.,ncol=4)

    else: 
        KOG_TPM_Hash[keys].T.plot(kind='bar', cmap=ccmap, stacked=True, title=keys,ax=ax,grid=False, legend=False)
fig.savefig('Percentage_E1_KOG.pdf')

# %%
rawKeys = [s for s in keys if "raw" in s]
rawKeys=sorted(rawKeys)
Ehux_Summed_TPM_KOG=pd.DataFrame(columns=rawKeys, index=KOG_TPM_Hash['E1-Q_raw'].index)

for key in rawKeys:
    v=KOG_TPM_Hash[key].sum(axis=1)
    Ehux_Summed_TPM_KOG[key]=v

Ehux_Summed_TPM_KOG=Ehux_Summed_TPM_KOG.drop('Unannotated')
Ehux_Summed_Percentage_KOG=Ehux_Summed_TPM_KOG/Ehux_Summed_TPM_KOG.sum()

def HeatMap(All_insitu_Percent, columns=None,colormap=b2m.sequential.YlOrRd_9.get_mpl_colormap(),m=1e-5):
    if columns:
        All_insitu_Percent=All_insitu_Percent[columns]
    # sckos=['SS1','SS2','SS3', 'SS4', 'SS5']
    All_insitu_Percent['mean']=All_insitu_Percent.mean(skipna=1, axis=1) #calculate mean value for each class

    All_insitu_Percent=All_insitu_Percent.sort(columns='mean', ascending=False)#Sort by the mean value

    All_insitu_Percent=All_insitu_Percent.drop('mean',1) #drop mean column
    All_insitu_Percent=All_insitu_Percent.loc[All_insitu_Percent.sum(axis=1)!=0]
    col_labels=list(All_insitu_Percent.index)
    row_labels=list(All_insitu_Percent.columns.values)
    fig3,ax3=plt.subplots()
    fig3.set_figheight(len(col_labels)/3)
    fig3.set_figwidth(len(row_labels))
    heatmap3 = ax3.pcolor(All_insitu_Percent, cmap=colormap, norm=LogNorm(vmin=m, vmax=All_insitu_Percent.max().max()))
    #heatmap3 = ax3.pcolor(All_insitu_Percent, cmap=plt.cm.jet, vmin=0, vmax=.25)
    ax3.set_xticks(np.arange(All_insitu_Percent.shape[1])+0.5, minor=False)
    ax3.set_yticks(np.arange(All_insitu_Percent.shape[0])+0.5, minor=False)
    ax3.invert_yaxis()
    ax3.xaxis.tick_top()
    ax3.margins(0,0)

    ax3.set_xticklabels(row_labels, minor=False)
    ax3.set_yticklabels(col_labels, minor=False)
    plt.colorbar(heatmap3)
    plt.show()
    return fig3
rawKeys = [s for s in keys if "raw" in s]
insituKeys = [s for s in rawKeys if "Z" in s]
insituKeys=sorted(insituKeys)
EKeys = [s for s in rawKeys if "E2" in s]
EKeys=sorted(EKeys)
E1Keys = [s for s in rawKeys if "E1" in s]
E1Keys=sorted(E1Keys)

# Insitu_HeatMap=HeatMap(Ehux_Summed_Percentage_KOG, columns=insituKeys)
# E2_Heatmap=HeatMap(Ehux_Summed_Percentage_KOG, columns=EKeys)
# E1_Heatmap=HeatMap(Ehux_Summed_Percentage_KOG, columns=E1Keys)
# Insitu_HeatMap.savefig('Insitu_KOGG_Heatmap.pdf')
# E1_Heatmap.savefig('E1_Heatmap_KOGG.pdf')
# E2_Heatmap.savefig('E2_Heatmap_KOGG.pdf')

# HeatMap(KOG_TPM_Hash['E1-R_percentage'])

# %%
def HeatMap_KOGG_Strain(All_insitu_Percent, columns=None,colormap=b2m.sequential.YlOrRd_9.get_mpl_colormap(),m=1e-5, rowOrder=None):
    if columns:
        All_insitu_Percent=All_insitu_Percent[columns]
    # sckos=['SS1','SS2','SS3', 'SS4', 'SS5']

#     All_insitu_Percent['mean']=All_insitu_Percent.mean(skipna=1, axis=1) #calculate mean value for each class
    All_insitu_Percent['MetaEhux']= All_insitu_Percent.sum(axis=1)
    All_insitu_Percent['MetaEhux']=All_insitu_Percent['MetaEhux']/All_insitu_Percent['MetaEhux'].sum()
    newOrder=['MetaEhux']+columns
    All_insitu_Percent=All_insitu_Percent.sort(columns='MetaEhux', ascending=False)#Sort by the mean value
    if rowOrder==None:
        All_insitu_Percent=All_insitu_Percent.sort(columns='MetaEhux', ascending=False)#Sort by the mean value
    else:     
        All_insitu_Percent=All_insitu_Percent.loc[rowOrder]
#     All_insitu_Percent=All_insitu_Percent.drop('mean',1) #drop mean column
    All_insitu_Percent=All_insitu_Percent.loc[All_insitu_Percent.sum(axis=1)!=0]
    col_labels=list(All_insitu_Percent.index)
    row_labels=list(All_insitu_Percent.columns.values)
    fig3,ax3=plt.subplots()
    fig3.set_figheight(float(len(col_labels))/4)
    fig3.set_figwidth(float(len(row_labels))/3)
    heatmap3 = ax3.pcolor(All_insitu_Percent, cmap=colormap, norm=LogNorm(vmin=m, vmax=All_insitu_Percent.max().max()))
    #heatmap3 = ax3.pcolor(All_insitu_Percent, cmap=plt.cm.jet, vmin=0, vmax=.25)
    ax3.set_xticks(np.arange(All_insitu_Percent.shape[1])+0.5, minor=False)
    ax3.set_yticks(np.arange(All_insitu_Percent.shape[0])+0.5, minor=False)
    ax3.invert_yaxis()
    ax3.xaxis.tick_top()
    ax3.margins(0,0)

    ax3.set_xticklabels(row_labels, minor=False)
    ax3.set_yticklabels(col_labels, minor=False)
    plt.colorbar(heatmap3)
    plt.show()
    return fig3,list(All_insitu_Percent.index), All_insitu_Percent

cols=KEGG_TPM_Hash['E1-Q_percentage'].columns

a=[s for s in cols if (len(s)==11)|(len(s)==50)]

fig,h, E2Z5=HeatMap_KOGG_Strain(KOG_TPM_Hash['E2-Z5_percentage'], a, m=1e-4)
fig2,j, E2R=HeatMap_KOGG_Strain(KOG_TPM_Hash['E2-R_percentage'], a, m=1e-4, rowOrder=h)
fig3,j, E2V=HeatMap_KOGG_Strain(KOG_TPM_Hash['E2-V_percentage'], a, m=1e-4, rowOrder=h)
fig4,j, E2X=HeatMap_KOGG_Strain(KOG_TPM_Hash['E2-X_percentage'], a, m=1e-4, rowOrder=h)

fig.savefig('E2_Z_KOG_Heatmap.pdf')
fig2.savefig('E2_R_KOG_Heatmap.pdf')
fig3.savefig('E2_V_KOG_Heatmap.pdf')
fig4.savefig('E2_X_KOG_Heatmap.pdf')
# Out:
# /Users/harrietalexander/anaconda/lib/python2.7/site-packages/IPython/kernel/__main__.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /Users/harrietalexander/anaconda/lib/python2.7/site-packages/IPython/kernel/__main__.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
import numpy, scipy
import scipy.cluster.hierarchy as hier
import scipy.spatial.distance as dist

distMatrix=dist.pdist(E2R.T)
distSqMatrix = dist.squareform(distMatrix)
linkageMatrix=hier.linkage(distSqMatrix)

# %%
def KOGG_Strain_dendrogram(All_insitu_Percent, columns=None,colormap=b2m.sequential.YlOrRd_9.get_mpl_colormap(),m=1e-5, rowOrder=None):
    if columns:
        All_insitu_Percent=All_insitu_Percent[columns]
    # sckos=['SS1','SS2','SS3', 'SS4', 'SS5']

#     All_insitu_Percent['mean']=All_insitu_Percent.mean(skipna=1, axis=1) #calculate mean value for each class
    All_insitu_Percent['MetaEhux']= All_insitu_Percent.sum(axis=1)
    All_insitu_Percent['MetaEhux']=All_insitu_Percent['MetaEhux']/All_insitu_Percent['MetaEhux'].sum()
    All_insitu_Percent=All_insitu_Percent.loc[All_insitu_Percent.sum(axis=1)!=0]
    return All_insitu_Percent

# %%
linkage_KOG_DF=pd.DataFrame(index=KOG_TPM_Hash['E2-Q_percentage'].index)
for key in KOG_TPM_Hash:
    if 'percentage' in key:
        if 'E3' in key:
            pass
        else:
            KDF=KOGG_Strain_dendrogram(KOG_TPM_Hash[key])
            KDF=KDF[a]
            nameDict={}
            for cols in KDF.columns:
                if cols in a:
                    if cols=="('Emi219', 'Emi370', 'Emi374', 'Emi379', 'Emihu1')":
                        c='Core'
                    else:
                        c=cols
                    newCol=c+'_'+key.split('_')[0]
                    nameDict[cols]=newCol 
                    
            KDF.rename(columns=nameDict, inplace=True)
            linkage_KOG_DF=linkage_KOG_DF.join(KDF)

# %%
linkage_KOG_DF=linkage_KOG_DF.dropna()

# %%
import numpy, scipy
import scipy.cluster.hierarchy as hier
import scipy.spatial.distance as dist
def CreateDendrogram(inDF):
    distMatrix=dist.pdist(inDF.T, 'correlation' )
    distSqMatrix = dist.squareform(distMatrix)
    linkageMatrix=hier.linkage(distSqMatrix) 
    dendro = hier.dendrogram(linkageMatrix)

    #get the order of rows according to the dendrogram 
    leaves = dendro['leaves'] 
    dendro=hier.dendrogram(linkageMatrix, labels=inDF.columns[leaves])
    print dendro.keys()

    D=CreateDendrogram(linkage_KOG_DF)
    
dendro=hier.dendrogram(linkageMatrix,)
dendro
# Out:
# {'color_list': ['g', 'g', 'g', 'g', 'g', 'b'],
#  'dcoord': [[0.0, 0.19918813502314348, 0.19918813502314348, 0.0],
#   [0.0, 0.20059091015148897, 0.20059091015148897, 0.19918813502314348],
#   [0.0, 0.21963731249414356, 0.21963731249414356, 0.20059091015148897],
#   [0.0, 0.25337183844357231, 0.25337183844357231, 0.21963731249414356],
#   [0.0, 0.37259472590856041, 0.37259472590856041, 0.25337183844357231],
#   [0.0, 0.61174689202021271, 0.61174689202021271, 0.37259472590856041]],
#  'icoord': [[55.0, 55.0, 65.0, 65.0],
#   [45.0, 45.0, 60.0, 60.0],
#   [35.0, 35.0, 52.5, 52.5],
#   [25.0, 25.0, 43.75, 43.75],
#   [15.0, 15.0, 34.375, 34.375],
#   [5.0, 5.0, 24.6875, 24.6875]],
#  'ivl': ['4', '1', '3', '5', '2', '0', '6'],
#  'leaves': [4, 1, 3, 5, 2, 0, 6]}

# %%
import scipy.cluster.hierarchy as sch
import scipy.spatial.distance as dist
import matplotlib.pylab as pylab
def CreateDendrogram(inDF):
    distMatrix=dist.pdist(inDF.T, 'correlation')
    distSqMatrix = dist.squareform(distMatrix)
    linkageMatrix=hier.linkage(distMatrix) 
    dendro = hier.dendrogram(linkageMatrix)

    #get the order of rows according to the dendrogram 
    leaves = dendro['leaves'] 
    dendro=hier.dendrogram(linkageMatrix, labels=inDF.columns[leaves])
# Generate random features and distance matrix.
#     x = scipy.rand(40)
#     D = scipy.zeros([40,40])
#     for i in range(40):
#         for j in range(40):
#             D[i,j] = abs(x[i] - x[j])

    D=distSqMatrix
    # Compute and plot first dendrogram.
    fig = pylab.figure(figsize=(8,8))
    ax1 = fig.add_axes([0.09,0.1,0.2,0.6])
    Y = sch.linkage(D, method='centroid')
    Z1 = sch.dendrogram(Y, orientation='right')
    ax1.set_xticks([])
    ax1.set_yticks([])

    # Compute and plot second dendrogram.
    ax2 = fig.add_axes([0.3,0.71,0.6,0.2])
    Y = sch.linkage(D, method='single')
    Z2 = sch.dendrogram(Y)
    ax2.set_xticks([])
    ax2.set_yticks([])

    # Plot distance matrix.
    axmatrix = fig.add_axes([0.3,0.1,0.6,0.6])
    idx1 = Z1['leaves']
    idx2 = Z2['leaves']
    D = D[idx1,:]
    D = D[:,idx2]
    im = axmatrix.matshow(D, aspect='auto', origin='lower', cmap=pylab.cm.YlGnBu)
#     axmatrix.set_xticks([])
#     axmatrix.set_yticks([])

    # Plot colorbar.
    axmatrix.set_xticks(range(len(inDF.T.index)))
    axmatrix.set_xticklabels(inDF.columns[idx1], minor=False)
    axmatrix.xaxis.set_label_position('bottom')
    axmatrix.xaxis.tick_bottom()

    pylab.xticks(rotation=-90, fontsize=8)

    axmatrix.set_yticks(range(len(inDF.T.index)))
    axmatrix.set_yticklabels(idx2, minor=False)
    axmatrix.yaxis.set_label_position('right')
    axmatrix.yaxis.tick_right()

    axcolor = fig.add_axes([0.91,0.1,0.02,0.6])
    pylab.colorbar(im, cax=axcolor)
    fig.show()
    fig.savefig('/Users/harrietalexander/Dropbox (MIT)/dendrogram.pdf')


CreateDendrogram(linkage_KOG_DF)

# %%
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-26-612a73b90251> in <module>()
# ----> 1 scipy.stats.pearsonr
#
# AttributeError: 'module' object has no attribute 'stats'
